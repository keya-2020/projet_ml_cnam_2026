# %%
# ==========================================================
# DATA_QUALITY.PY
# ==========================================================

import pandas as pd
import numpy as np

# ==========================================================
# LOAD DATA
# ==========================================================
df = pd.read_csv("Base.csv")

# ==========================================================
# MISSING VALUES
# ==========================================================
print("\n--- MISSING VALUES ---")

missing = df.isnull().sum()

missing_pct = 100 * missing / len(df)

missing_df = pd.DataFrame({
    "missing_count": missing,
    "missing_pct": missing_pct
})

missing_df = missing_df.sort_values(
    by="missing_pct",
    ascending=False
)

print(missing_df)

# ==========================================================
# DUPLICATES
# ==========================================================
print("\n--- DUPLICATES ---")

duplicates = df.duplicated().sum()

print(f"Duplicates: {duplicates}")

# ==========================================================
# DATA TYPES
# ==========================================================
print("\n--- DATA TYPES ---")

print(df.dtypes)

# ==========================================================
# UNIQUE VALUES
# ==========================================================
print("\n--- UNIQUE VALUES ---")

for col in df.columns:

    print(f"{col}: {df[col].nunique()} unique values")

# ==========================================================
# CONSTANT FEATURES
# ==========================================================
constant_cols = [
    col for col in df.columns
    if df[col].nunique() <= 1
]

print("\n--- CONSTANT COLUMNS ---")

print(constant_cols)

# ==========================================================
# OUTLIER DETECTION (IQR)
# ==========================================================
print("\n--- OUTLIER ANALYSIS ---")

num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[
        (df[col] < lower) |
        (df[col] > upper)
    ]

    pct = 100 * len(outliers) / len(df)

    print(f"{col}: {pct:.2f}% outliers")

print("\nDATA QUALITY COMPLETED")
# Out:
# --- MISSING VALUES ---
#                                   missing_count  missing_pct
# fraud_bool                                    0          0.0
# income                                        0          0.0
# name_email_similarity                         0          0.0
# prev_address_months_count                     0          0.0
# current_address_months_count                  0          0.0
# customer_age                                  0          0.0
# days_since_request                            0          0.0
# intended_balcon_amount                        0          0.0
# payment_type                                  0          0.0
# zip_count_4w                                  0          0.0
# velocity_6h                                   0          0.0
# velocity_24h                                  0          0.0
# velocity_4w                                   0          0.0
# bank_branch_count_8w                          0          0.0
# date_of_birth_distinct_emails_4w              0          0.0
# employment_status                             0          0.0
# credit_risk_score                             0          0.0
# email_is_free                                 0          0.0
# housing_status                                0          0.0
# phone_home_valid                              0          0.0
# phone_mobile_valid                            0          0.0
# bank_months_count                             0          0.0
# has_other_cards                               0          0.0
# proposed_credit_limit                         0          0.0
# foreign_request                               0          0.0
# source                                        0          0.0
# session_length_in_minutes                     0          0.0
# device_os                                     0          0.0
# keep_alive_session                            0          0.0
# device_distinct_emails_8w                     0          0.0
# device_fraud_count                            0          0.0
# month                                         0          0.0
#
# --- DUPLICATES ---
# Duplicates: 0
#
# --- DATA TYPES ---
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# bank_months_count                     int64
# has_other_cards                       int64
# proposed_credit_limit               float64
# foreign_request                       int64
# source                               object
# session_length_in_minutes           float64
# device_os                            object
# keep_alive_session                    int64
# device_distinct_emails_8w             int64
# device_fraud_count                    int64
# month                                 int64
# dtype: object
#
# --- UNIQUE VALUES ---
# fraud_bool: 2 unique values
# income: 9 unique values
# name_email_similarity: 998861 unique values
# prev_address_months_count: 374 unique values
# current_address_months_count: 423 unique values
# customer_age: 9 unique values
# days_since_request: 989330 unique values
# intended_balcon_amount: 994971 unique values
# payment_type: 5 unique values
# zip_count_4w: 6306 unique values
# velocity_6h: 998687 unique values
# velocity_24h: 998940 unique values
# velocity_4w: 998318 unique values
# bank_branch_count_8w: 2326 unique values
# date_of_birth_distinct_emails_4w: 40 unique values
# employment_status: 7 unique values
# credit_risk_score: 551 unique values
# email_is_free: 2 unique values
# housing_status: 7 unique values
# phone_home_valid: 2 unique values
# phone_mobile_valid: 2 unique values
# bank_months_count: 33 unique values
# has_other_cards: 2 unique values
# proposed_credit_limit: 12 unique values
# foreign_request: 2 unique values
# source: 2 unique values
# session_length_in_minutes: 994887 unique values
# device_os: 5 unique values
# keep_alive_session: 2 unique values
# device_distinct_emails_8w: 4 unique values
# device_fraud_count: 1 unique values
# month: 8 unique values
#
# --- CONSTANT COLUMNS ---
# ['device_fraud_count']
#
# --- OUTLIER ANALYSIS ---
# fraud_bool: 1.10% outliers
# income: 0.00% outliers
# name_email_similarity: 0.00% outliers
# prev_address_months_count: 15.73% outliers
# current_address_months_count: 4.10% outliers
# customer_age: 0.14% outliers
# days_since_request: 9.48% outliers
# intended_balcon_amount: 22.27% outliers
# zip_count_4w: 5.99% outliers
# velocity_6h: 0.90% outliers
# velocity_24h: 0.29% outliers
# velocity_4w: 0.00% outliers
# bank_branch_count_8w: 17.52% outliers
# date_of_birth_distinct_emails_4w: 0.97% outliers
# credit_risk_score: 0.87% outliers
# email_is_free: 0.00% outliers
# phone_home_valid: 0.00% outliers
# phone_mobile_valid: 11.03% outliers
# bank_months_count: 0.00% outliers
# has_other_cards: 22.30% outliers
# proposed_credit_limit: 24.17% outliers
# foreign_request: 2.52% outliers
# session_length_in_minutes: 7.88% outliers
# keep_alive_session: 0.00% outliers
# device_distinct_emails_8w: 3.19% outliers
# device_fraud_count: 0.00% outliers
# month: 0.00% outliers
#
# DATA QUALITY COMPLETED
